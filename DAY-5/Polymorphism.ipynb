# %%
class shape:
    def area(self,radius):
        return 3.14*radius**2
    def area(self,l,b):
        return l*b



s=shape()
s.area(2,3)
# Out:
# 6

# %%
#simple way to do this problem
class Shape:
    def area(self,radius,l,b):
        if b==None:
            print("radius")
            return 3.14*radius**2
        else:
            print("muiltiple")
            return l*b
    
s=Shape()
s.area(radius=2,l=20,b=1)
# Out:
# muiltiple
# 20
