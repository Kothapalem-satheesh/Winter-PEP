# %%
class user:
    def __init__(self):
        self.name="satheesh"
        self.gender="Male"
    def login(self):
        print("login done!")
    def register(self):
        print("register Done!")
          


class Student(user):
    def __init__(self):
        self.rollno=12
    def enroll(self):
        print("enrolled the course!")
        
        

class instructor(user):
    def __init__(self):
        self.idnumber=122
    def create(self):
        print("enrolled the course!")

# %%
a=Student()

# %%
a.enroll()
# Out:
# enrolled the course!

# %%
a.login()
# Out:
# login done!

# %%
i=instructor()

# %%
i.login()
# Out:
# login done!

# %%
class user:
    def __init__(self):
        self.name="satheesh"
        self.gender="Male"
    def login(self):
        print("login done!")
    def register(self):
        print("register Done!")
          


class Student(user):
    def __init__(self):
        self.rollno=12
    def enroll(self):
        print("enrolled the course!")

# %%
s=Student()
s.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 s=Student()
# ----> 2 s.name
#
# AttributeError: 'Student' object has no attribute 'name'

# %%
s.rollno
# Out:
# 12

# %%
class Phone:
    def __init__(self,price,brand,camera):
        print("inside the phone constructor ")
        self.price=price
        self.brand=brand
        self.camera=camera
    def buy(self):
        print("buyinga phone")
class SmartPhone(Phone):
    pass


s=SmartPhone("20000","apple",3)
s.buy()
# Out:
# inside the phone constructor
# buyinga phone

# %%
class Phone:
    def __init__(self,price,brand,camera):
        print("inside the phone constructor ")
        self.price=price
        self.brand=brand
        self.camera=camera
    def buy(self):
        print("buyinga phone")
class SmartPhone(Phone):
    def __init__(self,os,ram):#first pripority
        self.os=os
        self.ram=ram
        print("inside smartphone constructor")


s=SmartPhone("windows","12gb")
s.buy()
# Out:
# inside smartphone constructor
# buyinga phone

# %%
class Phone:
    def __init__(self,price,brand,camera):
        print("inside the phone constructor ")
        self.__price=price
        self.brand=brand
        self.camera=camera
    def get_price(self):
        return self.__price
    def buy(self):
        print("buyinga phone")
        
        
        
class SmartPhone(Phone):
   def print_price(self):
       print(self.get_price())


s=SmartPhone("20000","apple",3)
s.print_price()
# Out:
# inside the phone constructor
# 20000
