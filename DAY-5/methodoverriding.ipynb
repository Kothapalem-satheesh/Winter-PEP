# %%
class Phone:
    def __init__(self,price,brand,camera):
        print("inside the phone constructor ")
        self.__price=price
        self.brand=brand
        self.camera=camera
    def get_price(self):
        return self.__price
    def buy(self):
        print("inside smartphone phone")
        
        
        
class SmartPhone(Phone):
   def buy(self):
       print("inside smartphone")


s=SmartPhone("20000","apple",3)
s.buy()
# Out:
# inside the phone constructor
# inside smartphone
