# %%
class Customer:
    def __init__(self,name,gender,address):
        self.name=name
        self.gender=gender
        self.address=address 
    def print_info(self):
        print(f"name:{self.name},gender:{self.gender},address:{self.address.city},{self.address.pin},{self.address.state}")

class Address:
    def __init__(self,city,pin,state):
        self.city=city
        self.pin=pin
        self.state=state

# %%
add=Address("karnataka",2211,"karnataka")
cus=Customer("satheesh","male",add)

# %%
cus.print_info()
# Out:
# name:satheesh,gender:male,address:karnataka,2211,karnataka

# %%
class Customer:
    def __init__(self,name,gender,address):
        self.name=name
        self.gender=gender
        self.address=address 
    def print_info(self):
        print(f"name:{self.name},gender:{self.gender},address:{self.address.__city},{self.address.pin},{self.address.state}")

class Address:
    def __init__(self,city,pin,state):
        self.__city=city #private 
        self.pin=pin
        self.state=state

# %%
add=Address("karnataka",2211,"karnataka")
cus=Customer("satheesh","male",add)

# %%
cus.print_info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 cus.print_info()
#
# Cell In[25], line 7, in Customer.print_info(self)
#       6 def print_info(self):
# ----> 7     print(f"name:{self.name},gender:{self.gender},address:{self.address.__city},{self.address.pin},{self.address.state}")
#
# AttributeError: 'Address' object has no attribute '_Customer__city'

# %%
class Customer:
    def __init__(self,name,gender,address):
        self.name=name
        self.gender=gender
        self.address=address 
    def print_info(self):
        print(f"name:{self.name},gender:{self.gender},address:{self.address.get_city()},{self.address.pin},{self.address.state}")

class Address:
    def __init__(self,city,pin,state):
        self.__city=city #private 
        self.pin=pin
        self.state=state
    def get_city(self):
        return self.__city

# %%
add=Address("karnataka",2211,"karnataka")
cus=Customer("satheesh","male",add)

# %%
cus.print_info()
# Out:
# name:satheesh,gender:male,address:karnataka,2211,karnataka

# %%
class Customer:
    def __init__(self,name,gender,address):
        self.name=name
        self.gender=gender
        self.address=address 
    def print_info(self):
        print(f"name:{self.name},gender:{self.gender},address:{self.address._Address__city},{self.address.pin},{self.address.state}")

class Address:
    def __init__(self,city,pin,state):
        self.__city=city #private 
        self.pin=pin
        self.state=state
    # def get_city(self):
    #     return self.__city

# %%
add=Address("karnataka",2211,"karnataka")
cus=Customer("satheesh","male",add)

# %%
cus.print_info()
# Out:
# name:satheesh,gender:male,address:karnataka,2211,karnataka
