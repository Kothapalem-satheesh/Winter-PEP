# %%
class Phone:
    def __init__(self,price,brand,camera):
        print("inside the phone constructor ")
        self.__price=price
        self.brand=brand
        self.camera=camera
    def get_price(self):
        return self.__price
    def buy(self):
        print("inside smartphone phone")
        
        
        
class SmartPhone(Phone):
   def buy(self):
       print("inside smartphone")
       super().buy()


s=SmartPhone("20000","apple",3)
s.buy()
# Out:
# inside the phone constructor
# inside smartphone
# inside smartphone phone

# %%
class phone:
    def __init__(self,price,brand,camera):
        print("inside phone constructor")
        self.price=price
        self.brand=brand
        self.camera=camera
class smartPhone(phone):
    def __init__(self,price,brand,camera,os,ram):
        print("inside smartphone constructor")
        super().__init__(price,brand,camera)
        self.os=os
        self.ram=ram
    
    
        
        
s=smartPhone(1200,"lenovo","12","android",16)
# Out:
# inside smartphone constructor
# inside phone constructor

# %%
s.price
# Out:
# 1200
